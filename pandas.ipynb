# %%
import numpy as np
a=np.array([1,2,3])
b=np.array([4,5,6])
np.vstack((a,b))
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
np.hstack((a,b))
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
np.save("arr_num.npy",a)

# %%
arr=np.load("arr_num.npy")

# %%
arr
# Out:
# array([1, 2, 3])

# %% [markdown]
# #pandas

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
x={
    "name":["sana","ahmed"],
    "age":[20,90],
    "course":["ai","cs"]
}

# %%
x["name"]
# Out:
# ['sana', 'ahmed']

# %%
df=pd.DataFrame(x,index=["one","two"])

# %%
df
# Out:
#       name  age course
# one   sana   20     ai
# two  ahmed   90     cs

# %%
df["name"]
# Out:
# one     sana
# two    ahmed
# Name: name, dtype: object

# %%
df=pd.DataFrame({
    "name":["sana","ahmed"],
    "age":[20,90],
    "course":["ai","cs"]
},index=["one","two"])

# %%
df
# Out:
#       name  age course
# one   sana   20     ai
# two  ahmed   90     cs

# %%
df.iloc[0]
# Out:
# name      sana
# age         20
# course      ai
# Name: one, dtype: object

# %%
df.loc["one"]
# Out:
# name      sana
# age         20
# course      ai
# Name: one, dtype: object

# %%
df=pd.DataFrame({
    "name":["sana","ahmed","ali","soo"],
    "age":[20,90,80,90],
    "course":["ai","cs","bi","html"]
})

# %%
df
# Out:
#     name  age course
# 0   sana   20     ai
# 1  ahmed   90     cs
# 2    ali   80     bi
# 3    soo   90   html

# %%
df["age"].unique()
# Out:
# array([20, 90, 80])

# %%
df["age"].value_counts()
# Out:
# age
# 90    2
# 20    1
# 80    1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   age     4 non-null      int64
#  2   course  4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#              age
# count   4.000000
# mean   70.000000
# std    33.665016
# min    20.000000
# 25%    65.000000
# 50%    85.000000
# 75%    90.000000
# max    90.000000

# %%
df["age"]>80
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# Name: age, dtype: bool

# %%
df[df["age"]>80]
# Out:
#     name  age course
# 1  ahmed   90     cs
# 3    soo   90   html

# %%
df.rename({"name":"name_stu"},axis=1,inplace=True)

# %%
df
# Out:
#   name_stu  age course
# 0     sana   20     ai
# 1    ahmed   90     cs
# 2      ali   80     bi
# 3      soo   90   html

# %%
df.sort_values("age",inplace=True)

# %%
df
# Out:
#   name_stu  age course
# 0     sana   20     ai
# 2      ali   80     bi
# 1    ahmed   90     cs
# 3      soo   90   html

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#    index name_stu  age course
# 0      0     sana   20     ai
# 1      2      ali   80     bi
# 2      1    ahmed   90     cs
# 3      3      soo   90   html

# %%
df.drop(columns=["index"])
# Out:
#   name_stu  age course
# 0     sana   20     ai
# 1      ali   80     bi
# 2    ahmed   90     cs
# 3      soo   90   html

# %%
df["salary"]=[300,400,600,700]

# %%
df
# Out:
#    index name_stu  age course  salary
# 0      0     sana   20     ai     300
# 1      2      ali   80     bi     400
# 2      1    ahmed   90     cs     600
# 3      3      soo   90   html     700

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     4 non-null      int64
#  1   name_stu  4 non-null      object
#  2   age       4 non-null      int64
#  3   course    4 non-null      object
#  4   salary    4 non-null      int64
# dtypes: int64(3), object(2)
# memory usage: 292.0+ bytes

# %%
df.course=df.course.replace("ai","html")

# %%
df
# Out:
#    index name_stu  age course  salary
# 0      0     sana   20   html     300
# 1      2      ali   80     bi     400
# 2      1    ahmed   90     cs     600
# 3      3      soo   90   html     700

# %%
df
# Out:
#    index name_stu  age course  salary
# 0      0     sana   20   html     300
# 1      2      ali   80     bi     400
# 2      1    ahmed   90     cs     600
# 3      3      soo   90   html     700

# %%
df=pd.read_csv("Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
len(df)#num of rows
# Out:
# 150

# %%
df.shape
# Out:
# (150, 6)

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.head(6)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa

# %%
df.tail(6)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.Species#num of classes
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
df.Species.unique()#num of classes
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.Species.value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
len(df)
# Out:
# 150

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.drop_duplicates(keep="last",inplace=True)#version

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.drop(columns=["Id"],inplace=True)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df=pd.read_csv("student_scores.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 532.0 bytes

# %%
df
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
df.tail()
# Out:
#     Hours  Scores
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
df.isnull()
# Out:
#     Hours  Scores
# 0   False   False
# 1   False   False
# 2   False   False
# 3   False   False
# 4   False   False
# 5   False   False
# 6   False   False
# 7   False   False
# 8   False   False
# 9   False   False
# 10  False   False
# 11  False   False
# 12  False   False
# 13  False   False
# 14  False   False
# 15  False   False
# 16  False   False
# 17  False   False
# 18  False   False
# 19  False   False
# 20  False   False
# 21  False   False
# 22  False   False
# 23  False   False
# 24  False   False

# %%
df.isnull().sum()
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 532.0 bytes

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(keep="last",inplace=True)#version

# %% [markdown]
# ## sana

# %%
df.Scores.value_counts()
# Out:
# Scores
# 30    3
# 47    1
# 21    1
# 27    1
# 75    1
# 20    1
# 88    1
# 60    1
# 81    1
# 25    1
# 85    1
# 62    1
# 41    1
# 42    1
# 17    1
# 95    1
# 24    1
# 67    1
# 69    1
# 54    1
# 35    1
# 76    1
# 86    1
# Name: count, dtype: int64

# %%
df=pd.DataFrame({
    "name":["sana","ahmed","ali","wael"],
    "age":[20,90,50,38],
    "course":["ai","cs","bio","re"]
})

# %%
import numpy as np

# %%
df["bonus"]=np.random.randint(100,300000,size=len(df))

# %%
df
# Out:
#     name  age course   bonus
# 0   sana   20     ai  173622
# 1  ahmed   90     cs  121378
# 2    ali   50    bio  162085
# 3   wael   38     re  192637

# %%
df.bonus.cumsum()
# Out:
# 0    173622
# 1    295000
# 2    457085
# 3    649722
# Name: bonus, dtype: int64

# %%
df.bonus.cummax()
# Out:
# 0    173622
# 1    173622
# 2    173622
# 3    192637
# Name: bonus, dtype: int32

# %%
df.bonus.cummin()
# Out:
# 0    173622
# 1    121378
# 2    121378
# 3    121378
# Name: bonus, dtype: int32

# %%
df["cummin"]=df.bonus.cummin()

# %%
df
# Out:
#     name  age course   bonus  cummin
# 0   sana   20     ai  173622  173622
# 1  ahmed   90     cs  121378  121378
# 2    ali   50    bio  162085  121378
# 3   wael   38     re  192637  121378

# %%
df=df[["name","cummin"]]

# %%
df
# Out:
#     name  cummin
# 0   sana  173622
# 1  ahmed  121378
# 2    ali  121378
# 3   wael  121378

# %%
df.to_csv("Employee Data.csv")

# %%
melt_df=pd.melt(df)

# %%
melt_df
# Out:
#   variable   value
# 0     name    sana
# 1     name   ahmed
# 2     name     ali
# 3     name    wael
# 4   cummin  173622
# 5   cummin  121378
# 6   cummin  121378
# 7   cummin  121378

# %%
melt_df.head()
# Out:
#   variable   value
# 0     name    sana
# 1     name   ahmed
# 2     name     ali
# 3     name    wael
# 4   cummin  173622

# %%
pivot_df=melt_df.pivot(columns="variable",values="value")

# %%
pivot_df
# Out:
# variable  cummin   name
# 0            NaN   sana
# 1            NaN  ahmed
# 2            NaN    ali
# 3            NaN   wael
# 4         173622    NaN
# 5         121378    NaN
# 6         121378    NaN
# 7         121378    NaN

# %%
melt_df.head()
# Out:
#   variable   value
# 0     name    sana
# 1     name   ahmed
# 2     name     ali
# 3     name    wael
# 4   cummin  173622

# %%
melt_df["index"]=melt_df.groupby("variable").cumcount()

# %%
melt_df
# Out:
#   variable   value  index
# 0     name    sana      0
# 1     name   ahmed      1
# 2     name     ali      2
# 3     name    wael      3
# 4   cummin  173622      0
# 5   cummin  121378      1
# 6   cummin  121378      2
# 7   cummin  121378      3

# %%
pivot_df=melt_df.pivot(index="index",columns="variable",values="value")

# %%
pivot_df=melt_df.pivot(columns="variable",values="value")
# Out:
# variable  cummin   name
# index
# 0         173622   sana
# 1         121378  ahmed
# 2         121378    ali
# 3         121378   wael

# %%
pivot_df.reset_index(inplace=True)

# %%
pivot_df
# Out:
# variable  index  cummin   name
# 0             0  173622   sana
# 1             1  121378  ahmed
# 2             2  121378    ali
# 3             3  121378   wael

# %%
pivot_df.drop(columns=["index"],inplace=True)

# %%
pivot_df
# Out:
# variable  cummin   name
# 0         173622   sana
# 1         121378  ahmed
# 2         121378    ali
# 3         121378   wael

# %%
pivot_df.columns
# Out:
# Index(['cummin', 'name'], dtype='object', name='variable')

# %%
pivot_df.columns.name=None

# %%
pivot_df
# Out:
#    cummin   name
# 0  173622   sana
# 1  121378  ahmed
# 2  121378    ali
# 3  121378   wael

# %%
pivot_df.sample()
# Out:
#    cummin  name
# 3  121378  wael

# %%
pivot_df.query(('name=="sana"'))
# Out:
#    cummin  name
# 0  173622  sana
